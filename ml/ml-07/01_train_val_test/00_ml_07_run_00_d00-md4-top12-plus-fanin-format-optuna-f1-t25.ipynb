# %% [markdown]
# # ML common XGBoost Native Categorical Run
#
# `ml_inputs`에 승인 배치된 experiment 입력을 사용해 XGBoost 학습/validation 흐름을 실행한다.

# %% [markdown]
# ## 실행 범위
#
# - `fb_outputs` 검토 후 `ml_inputs/{RUN_ID}`에 승인 배치된 `{ARTIFACT_PREFIX}` 입력을 사용한다.
# - `encoding_manifest.json`을 `XGBTrainConfig`에 전달해 native categorical dtype을 복원한다.
# - train split으로 모델을 학습하고 validation split에서 threshold와 metric을 산출한다.
# - feature 생성이나 `fb_outputs -> ml_inputs` 복사는 수행하지 않는다.
# - exp 식별자는 설정 셀의 `EXPORT_EXPERIMENT_ID`, `RUN_ID`, `MODEL_RUN_ID`에서만 지정한다.
# - final test는 기본 실행하지 않는다. full validation artifact 확정 후 사용자가 `RUN_FINAL_TEST=True`로 전환해 실행한다.

# %% [markdown]
# ## 실행 전 주의
#
# - 입력 feature set은 `*_feature_contract_approve.csv`에서 `used_in_ml=TRUE`인 컬럼을 기준으로 한다.
# - native categorical dtype 복원에는 같은 run directory의 `encoding_manifest.json`이 필요하다.
# - threshold 선택은 validation set에서만 수행하고, test set은 `RUN_FINAL_TEST=True`일 때만 사용한다.
# - 기본 overwrite는 `False`다. 같은 설정으로 재실행하려면 `MODEL_RUN_ID` 변경을 권장한다.

# %% [markdown]
# ## Optuna best 모델 선택 워크플로
# - `RUN_TUNING=True`는 smoke/full tuning을 실행한 뒤 full study의 best params로 root `ml_outputs/<RUN_ID>/`에 ML-01과 동일한 최종 산출물 세트를 만든다.
# - root 최종 산출물만 validation 비교와 리더보드 후보로 사용한다. `optuna__<MODEL_RUN_ID>/` 아래 smoke/full/best 로그는 참고용이며 필요하면 수기로 옮긴다.
# - validation 결과가 마음에 들지 않으면 `MODEL_RUN_ID`를 바꿔 다시 Optuna를 실행한다. 예: `d01-optuna-ap`, `d02-optuna-f1`, `d03-optuna-ap-100trials`.
# - validation 결과가 마음에 드는 `MODEL_RUN_ID` 하나를 최종 후보로 확정한 뒤, 그 `MODEL_RUN_ID`로 final test를 1회만 실행한다.
# - final test는 best params를 직접 읽지 않는다. Optuna가 이미 best params로 만든 root `_model.pkl`, `_train_summary.json`, `_threshold.json`을 읽으므로 best param이 자동 반영된다.
# - final test 단계에서는 학습/검증 셀을 다시 실행하지 않는다. 설정 셀에서 `MODEL_RUN_ID`, `RUN_FINAL_TEST=True`를 맞춘 뒤 `03_final test 잠금` 셀만 실행한다.
# - test 결과를 보고 다시 `MODEL_RUN_ID`를 고르면 test leakage가 된다. test는 최종 후보 1개에 대해서만 사용한다.

# %% [markdown]
# # 00_경로 및 환경설정

# %%
from __future__ import annotations
import sys
from pathlib import Path

# ============================================================
# 0.1 Runtime Settings
# 실행 환경: ML 담당자 기준
# - Kernel          : Local WSL
# - Code repo       : local Git repo
# - Input artifacts : local Git repo ml/<exp-id>/ml_inputs/
# - Output artifacts: local Git repo ml/<exp-id>/ml_outputs/
# ============================================================
SEED = 42
EXPORT_EXPERIMENT_ID = "ml_07"
RUN_ID = "r00"
MODEL_RUN_ID = "ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25"

# Root Paths: 다른 환경에서 실행할 경우 보통 이 경로만 수정한다.
LOCAL_REPO_ROOT = Path("/mnt/d/AML_git/Graph_AML").resolve()

# Input/Output Paths
BASE_DIR = LOCAL_REPO_ROOT / "ml" / "ml-07"
ML_INPUTS_DIR = BASE_DIR / "ml_inputs"
ML_OUTPUTS_DIR = BASE_DIR / "ml_outputs"

# Module Code Paths: local Git repo에서 train_val_test 모듈을 import한다.
MODULE_DIR = BASE_DIR / "01_train_val_test"

# ============================================================
# 0.2 Path Validation
# ============================================================
def require_dir(path: Path, name: str) -> None:
    # 필수 디렉터리가 없으면 시작 단계에서 중단한다.
    path = Path(path).resolve()
    if not path.exists():
        raise FileNotFoundError(f"{name} not found: {path}")
    if not path.is_dir():
        raise NotADirectoryError(f"{name} is not a directory: {path}")

# ML-07 output root는 새 실험에서 처음 생성될 수 있으므로 설정 단계에서 준비한다.
ML_OUTPUTS_DIR.mkdir(parents=True, exist_ok=True)

# 시작 단계에서 반드시 존재해야 하는 디렉터리만 검증한다.
for name, path in {
    "LOCAL_REPO_ROOT": LOCAL_REPO_ROOT,
    "BASE_DIR": BASE_DIR,
    "ML_INPUTS_DIR": ML_INPUTS_DIR,
    "ML_OUTPUTS_DIR": ML_OUTPUTS_DIR,
    "MODULE_DIR": MODULE_DIR,
}.items():
    require_dir(path, name)

# ============================================================
# 0.3 Import Path Setup
# ============================================================
# local train_val_test/ml_*.py 모듈을 우선 import한다.
IMPORT_DIRS = [str(MODULE_DIR)]
IMPORT_MODULES = (
    "ml_cpugpu",
    "ml_utils",
    "ml_io",
    "ml_metrics",
    "ml_resource",
    "ml_optuna_spaces",
    "ml_train",
    "ml_val",
    "ml_test",
    "ml_optuna",
)

# 중복 경로를 제거한 뒤 맨 앞에 삽입해 import 우선순서를 고정한다.
sys.path = [path for path in sys.path if path not in IMPORT_DIRS]
sys.path[:0] = IMPORT_DIRS

# 노트북 재실행 시 수정된 local 모듈을 다시 읽도록 import cache를 제거한다.
for module_name in IMPORT_MODULES:
    sys.modules.pop(module_name, None)

import ml_cpugpu
import ml_utils
import ml_io
import ml_train
import ml_val
import ml_test
import ml_optuna

# train/validation/test 실행 전 난수 시드를 고정한다.
ml_utils.set_seed(SEED)

# ============================================================
# 0.4 Configuration Summary
# ============================================================
print("=" * 80)
print("SEED                 :", SEED)
print("EXPORT_EXPERIMENT_ID :", EXPORT_EXPERIMENT_ID)
print("RUN_ID               :", RUN_ID)
print("MODEL_RUN_ID         :", MODEL_RUN_ID)
print("LOCAL_REPO_ROOT      :", LOCAL_REPO_ROOT)
print("ML_INPUTS_DIR        :", ML_INPUTS_DIR)
print("ML_OUTPUTS_DIR       :", ML_OUTPUTS_DIR)
print("MODULE_DIR           :", MODULE_DIR)
print("=" * 80)
# Out:
# ================================================================================
# SEED                 : 42
# EXPORT_EXPERIMENT_ID : ml_07
# RUN_ID               : r00
# MODEL_RUN_ID         : ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25
# LOCAL_REPO_ROOT      : /mnt/d/AML_git/Graph_AML
# ML_INPUTS_DIR        : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs
# ML_OUTPUTS_DIR       : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs
# MODULE_DIR           : /mnt/d/AML_git/Graph_AML/ml/ml-07/01_train_val_test
# ================================================================================

# %% [markdown]
# # 01_실행 설정

# %%
# ============================================================
# 실행 예시
# ============================================================
# 예시 1. 고정 XGB_PARAMS full train/validation 실행
# - encoding manifest가 있는 승인 입력으로 모델 학습 + validation threshold 선택
# - final test는 아직 실행하지 않음
#   RUN_TUNING = False
#   SAMPLE_ROWS = None
#   RUN_FINAL_TEST = False
#
# 예시 2. Optuna tuning + best params final train/validation 실행
# - Optuna는 test split을 절대 호출하지 않음
#   RUN_TUNING = True
#   RUN_FINAL_TEST = False
#
# 예시 3. 기존 full artifact로 final test만 실행
# - 같은 OUT_DIR에 prefix 기반 model, feature_columns, train_summary, threshold 파일이 있을 때만 실행
# - train/validation은 다시 돌리지 않고 final test만 수행
#   RUN_FINAL_TEST = True
#
# 주의:
# - EXPORT_EXPERIMENT_ID / RUN_ID / MODEL_RUN_ID는 00_경로 및 환경설정 셀에서만 지정한다.
# - RUN_ID는 fb_outputs 검토 후 ml_inputs에 승인 배치된 입력 묶음 식별자다.
# - MODEL_RUN_ID는 같은 입력으로 반복하는 모델 학습/검증 시도 식별자다.
# - sample/full 구분은 RUN_ID와 JSON metadata의 sampled, sample_rows 필드로 관리한다.
# - OVERWRITE_OUTPUTS=False이면 기존 산출물이 있을 때 덮어쓰지 않고 중단한다.

# ============================================================
# 산출물 구분
# ============================================================
# <ML_ARTIFACT_PREFIX>_model.pkl                    -> train 결과
# <ML_ARTIFACT_PREFIX>_feature_columns.json          -> train 결과
# <ML_ARTIFACT_PREFIX>_train_summary.json            -> train 결과 + native categorical 설정 기록
# <ML_ARTIFACT_PREFIX>_scores_train_summary.json     -> train/val logloss learning curve
# <ML_ARTIFACT_PREFIX>_feature_importance.csv         -> train 결과, booster importance
# <ML_ARTIFACT_PREFIX>_threshold.json                -> validation 결과
# <ML_ARTIFACT_PREFIX>_metrics_val.json              -> validation 결과
# <ML_ARTIFACT_PREFIX>_confusion_matrix_val.csv      -> validation 결과
# <ML_ARTIFACT_PREFIX>_prediction_scores_val.parquet -> validation row별 score, EXPORT_PREDICTION_SCORES=True일 때
# feature association JSON                          -> EXPORT_FEATURE_ASSOC=True일 때 train/val/test 단계별 생성
# <ML_ARTIFACT_PREFIX>_metrics_test.json             -> final test 결과
# <ML_ARTIFACT_PREFIX>_confusion_matrix_test.csv     -> final test 결과

# ============================================================
# 1.1 Run identifiers
# ============================================================
ARTIFACT_PREFIX = f"{EXPORT_EXPERIMENT_ID}__{RUN_ID}"
ML_ARTIFACT_PREFIX = f"{ARTIFACT_PREFIX}__{MODEL_RUN_ID}"

# ============================================================
# 1.2 Input / output directories
# ============================================================
# ML_INPUT_DIR은 사람이 검토 후 승인 배치한 ML 입력 위치다.
# OUT_DIR은 train/validation/test artifact를 저장하는 최종 run directory다.
ML_INPUT_DIR = ML_INPUTS_DIR / RUN_ID
OUT_DIR = ML_OUTPUTS_DIR / RUN_ID
OPTUNA_OUTPUT_DIR = OUT_DIR / f"optuna__{MODEL_RUN_ID}"

# ============================================================
# 1.3 Input artifact paths
# ============================================================
# train/val/test parquet와 승인 feature contract는 같은 ARTIFACT_PREFIX를 사용한다.
# ENCODING_MANIFEST_PATH는 native categorical dtype 복원과 검증에 사용된다.
TRAIN_PATH = ML_INPUT_DIR / f"{ARTIFACT_PREFIX}_Xy_train.parquet"
VAL_PATH = ML_INPUT_DIR / f"{ARTIFACT_PREFIX}_Xy_val.parquet"
TEST_PATH = ML_INPUT_DIR / f"{ARTIFACT_PREFIX}_Xy_test.parquet"
FEATURE_COLUMNS_PATH = (
    ML_INPUT_DIR
    / f"{ARTIFACT_PREFIX}_fb_output_feature_contract_practical_plus_rev27_gain_top12_plus_fanin_format.csv"
)
ENCODING_MANIFEST_PATH = ML_INPUT_DIR / f"{ARTIFACT_PREFIX}_encoding_manifest.json"

MODEL_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_model.pkl"
FEATURE_COLUMNS_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_feature_columns.json"
TRAIN_SUMMARY_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_train_summary.json"
SCORES_TRAIN_SUMMARY_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_scores_train_summary.json"
FEATURE_IMPORTANCE_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_feature_importance.csv"
THRESHOLD_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_threshold.json"
METRICS_VAL_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_metrics_val.json"
CONFUSION_MATRIX_VAL_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_confusion_matrix_val.csv"
METRICS_TEST_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_metrics_test.json"
CONFUSION_MATRIX_TEST_FILE_NAME = f"{ML_ARTIFACT_PREFIX}_confusion_matrix_test.csv"

# ============================================================
# 1.4 Execution switches
# ============================================================
# RUN_TUNING=False이면 고정 XGB_PARAMS, True이면 Optuna best params로 train/validation을 실행한다.
# SAMPLE_ROWS는 고정 XGB_PARAMS smoke/debug 전용이다. Optuna full tuning에서는 항상 None이어야 한다.
# final test는 full model + validation threshold 확정 후 명시적으로 True로 바꾼다.
# EXPORT_FEATURE_ASSOC는 train/val/test feature association JSON 생성 여부를 제어한다.
# EXPORT_PREDICTION_SCORES는 validation row별 score parquet 생성 여부를 제어한다.
SAMPLE_ROWS = None
RUN_TUNING = True
RUN_FINAL_TEST = False
OVERWRITE_OUTPUTS = False

EXPORT_FEATURE_ASSOC = True
EXPORT_PREDICTION_SCORES = True

XGB_ACCELERATOR = "auto"  # auto | cpu | cuda

OPTUNA_SMOKE_TRIALS = 3
OPTUNA_FULL_TRIALS = 25
OPTUNA_SELECTION_METRIC = "f1"

# ============================================================
# 1.5 XGBoost parameters
# ============================================================

XGB_PARAMS = {
    "n_estimators": 300,
    "max_depth": 4,
    "learning_rate": 0.05,
    "subsample": 0.9,
    "colsample_bytree": 0.9,
    "min_child_weight": 1.0,
    "reg_lambda": 1.0,
    "reg_alpha": 0.0,
    "gamma": 0.0,
    "early_stopping_rounds": 30,
    "n_jobs": -1,
}

# ============================================================
# 1.6 Input contract object
# ============================================================
# native categorical 활성화 여부는 encoding manifest에서 복원된 categorical feature 존재 여부로 train 모듈이 결정한다.
# InputPaths에 encoding manifest를 포함해 train/val/test 단계가 같은 encoding 계약을 사용하게 한다.
INPUT_PATHS = ml_io.InputPaths(
    train_path=TRAIN_PATH,
    val_path=VAL_PATH,
    test_path=TEST_PATH,
    feature_columns_path=FEATURE_COLUMNS_PATH,
    encoding_manifest_path=ENCODING_MANIFEST_PATH,
)

# ============================================================
# 1.7 Configuration preview
# ============================================================
print("=" * 80)
print("EXPORT_EXPERIMENT_ID  :", EXPORT_EXPERIMENT_ID)
print("RUN_ID                :", RUN_ID)
print("MODEL_RUN_ID          :", MODEL_RUN_ID)
print("ARTIFACT_PREFIX       :", ARTIFACT_PREFIX)
print("ML_ARTIFACT_PREFIX    :", ML_ARTIFACT_PREFIX)
print("TRAIN_PATH            :", TRAIN_PATH)
print("VAL_PATH              :", VAL_PATH)
print("FEATURE_COLUMNS_PATH  :", FEATURE_COLUMNS_PATH)
print("ENCODING_MANIFEST_PATH:", ENCODING_MANIFEST_PATH)
print("OUT_DIR               :", OUT_DIR)
print("OPTUNA_OUTPUT_DIR     :", OPTUNA_OUTPUT_DIR)
print("EXPORT_FEATURE_ASSOC     :", EXPORT_FEATURE_ASSOC)
print("EXPORT_PREDICTION_SCORES :", EXPORT_PREDICTION_SCORES)
print("XGB_ACCELERATOR          :", XGB_ACCELERATOR)
print("=" * 80)
# Out:
# ================================================================================
# EXPORT_EXPERIMENT_ID  : ml_07
# RUN_ID                : r00
# MODEL_RUN_ID          : ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25
# ARTIFACT_PREFIX       : ml_07__r00
# ML_ARTIFACT_PREFIX    : ml_07__r00__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25
# TRAIN_PATH            : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_Xy_train.parquet
# VAL_PATH              : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_Xy_val.parquet
# FEATURE_COLUMNS_PATH  : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_fb_output_feature_contract_practical_plus_rev27_gain_top12_plus_fanin_format.csv
# ENCODING_MANIFEST_PATH: /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_encoding_manifest.json
# OUT_DIR               : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00
# OPTUNA_OUTPUT_DIR     : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00/optuna__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25
# EXPORT_FEATURE_ASSOC     : True
# EXPORT_PREDICTION_SCORES : True
# XGB_ACCELERATOR          : auto
# ================================================================================

# %% [markdown]
# # 02_train / validation 실행

# %%
# 입력 parquet, 승인 feature CSV, encoding manifest가 모두 존재하는지 먼저 확인한다.
ml_io.require_input_files(INPUT_PATHS, require_test=RUN_FINAL_TEST)
ml_io.print_input_paths(INPUT_PATHS)

if RUN_TUNING:
    optuna_config = ml_optuna.OptunaPipelineConfig(
        train_path=TRAIN_PATH,
        val_path=VAL_PATH,
        feature_columns_path=FEATURE_COLUMNS_PATH,
        tuning_output_dir=OPTUNA_OUTPUT_DIR,
        final_output_dir=OUT_DIR,
        encoding_manifest_path=ENCODING_MANIFEST_PATH,
        model_file_name=MODEL_FILE_NAME,
        feature_columns_file_name=FEATURE_COLUMNS_FILE_NAME,
        train_summary_file_name=TRAIN_SUMMARY_FILE_NAME,
        scores_train_summary_file_name=SCORES_TRAIN_SUMMARY_FILE_NAME,
        feature_importance_file_name=FEATURE_IMPORTANCE_FILE_NAME,
        threshold_file_name=THRESHOLD_FILE_NAME,
        metrics_val_file_name=METRICS_VAL_FILE_NAME,
        confusion_matrix_val_file_name=CONFUSION_MATRIX_VAL_FILE_NAME,
        smoke_trials=OPTUNA_SMOKE_TRIALS,
        full_trials=OPTUNA_FULL_TRIALS,
        selection_metric=OPTUNA_SELECTION_METRIC,
        study_name_prefix=EXPORT_EXPERIMENT_ID,
        seed=SEED,
        n_jobs=XGB_PARAMS["n_jobs"],
        accelerator=XGB_ACCELERATOR,
        overwrite=OVERWRITE_OUTPUTS,
    )
    optuna_result = ml_optuna.run_ml_optuna_pipeline(optuna_config)
    print("best_params_path  :", optuna_result.best_params_path)
    print("pipeline_summary  :", optuna_result.pipeline_summary_path)
    print("threshold_path    :", optuna_result.val_result.threshold_path)
    print("metrics_path      :", optuna_result.val_result.metrics_path)
else:
    # train_config는 train split, validation split, feature mask, native categorical manifest를 한 번에 묶는다.
    train_config = ml_train.XGBTrainConfig(
        train_path=TRAIN_PATH,
        val_path=VAL_PATH,
        feature_columns_path=FEATURE_COLUMNS_PATH,
        output_dir=OUT_DIR,
        model_file_name=MODEL_FILE_NAME,
        feature_columns_file_name=FEATURE_COLUMNS_FILE_NAME,
        train_summary_file_name=TRAIN_SUMMARY_FILE_NAME,
        scores_train_summary_file_name=SCORES_TRAIN_SUMMARY_FILE_NAME,
        feature_importance_file_name=FEATURE_IMPORTANCE_FILE_NAME,
        sample_rows=SAMPLE_ROWS,
        overwrite=OVERWRITE_OUTPUTS,
        seed=SEED,
        encoding_manifest_path=ENCODING_MANIFEST_PATH,
        export_feature_assoc=EXPORT_FEATURE_ASSOC,
        accelerator=XGB_ACCELERATOR,
        **XGB_PARAMS,
    )
    train_result = ml_train.train_xgb(train_config)

    # threshold 선택과 validation metric 산출은 validation split에서만 수행한다.
    val_config = ml_val.ValidationConfig(
        val_path=VAL_PATH,
        output_dir=OUT_DIR,
        model_file_name=MODEL_FILE_NAME,
        feature_columns_file_name=FEATURE_COLUMNS_FILE_NAME,
        train_summary_file_name=TRAIN_SUMMARY_FILE_NAME,
        scores_train_summary_file_name=SCORES_TRAIN_SUMMARY_FILE_NAME,
        threshold_file_name=THRESHOLD_FILE_NAME,
        metrics_file_name=METRICS_VAL_FILE_NAME,
        confusion_matrix_file_name=CONFUSION_MATRIX_VAL_FILE_NAME,
        sample_rows=SAMPLE_ROWS,
        overwrite=OVERWRITE_OUTPUTS,
        encoding_manifest_path=ENCODING_MANIFEST_PATH,
        export_feature_assoc=EXPORT_FEATURE_ASSOC,
        export_prediction_scores=EXPORT_PREDICTION_SCORES,
    )
    val_result = ml_val.validate_xgb(val_config)
    print("train_summary_path        :", train_result.train_summary_path)
    print("scores_train_summary_path :", train_result.scores_train_summary_path)
    print("threshold_path   :", val_result.threshold_path)
    print("metrics_path     :", val_result.metrics_path)
# Out:
# train_path          : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_Xy_train.parquet
# val_path            : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_Xy_val.parquet
# test_path           : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_Xy_test.parquet
# feature_columns_path: /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_fb_output_feature_contract_practical_plus_rev27_gain_top12_plus_fanin_format.csv
# encoding_manifest_path: /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_inputs/r00/ml_07__r00_encoding_manifest.json
# [I 2026-06-05 10:24:17,057] A new study created in memory with name: ml_07_smoke
# [I 2026-06-05 10:24:57,600] Trial 0 finished with value: 0.16993464052287585 and parameters: {'n_estimators': 1200, 'learning_rate': 0.05842709547450362, 'max_depth': 4, 'min_child_weight': 178.09483639586108, 'subsample': 0.75, 'colsample_bytree': 0.45, 'reg_lambda': 63.00065953319189, 'reg_alpha': 0.1255111517297383, 'gamma': 32.7249944781739, 'early_stopping_rounds': 50}. Best is trial 0 with value: 0.16993464052287585.
# [I 2026-06-05 10:25:33,781] Trial 1 finished with value: 0.1956521739130435 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05903473962504268, 'max_depth': 4, 'min_child_weight': 192.77345924989356, 'subsample': 0.65, 'colsample_bytree': 0.45, 'reg_lambda': 65.6118263910571, 'reg_alpha': 0.32877474139911184, 'gamma': 26.92085933774804, 'early_stopping_rounds': 35}. Best is trial 1 with value: 0.1956521739130435.
# [I 2026-06-05 10:26:11,189] Trial 2 finished with value: 0.17872340425531913 and parameters: {'n_estimators': 1600, 'learning_rate': 0.03773298947682867, 'max_depth': 4, 'min_child_weight': 125.9032537218751, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.5, 'reg_lambda': 160.02711590046482, 'reg_alpha': 0.21839352923182975, 'gamma': 26.741985453031397, 'early_stopping_rounds': 35}. Best is trial 1 with value: 0.1956521739130435.
# [I 2026-06-05 10:26:11,214] A new study created in memory with name: ml_07_full
# [I 2026-06-05 10:30:01,053] Trial 0 finished with value: 0.380952380952381 and parameters: {'n_estimators': 1200, 'learning_rate': 0.05842709547450362, 'max_depth': 4, 'min_child_weight': 178.09483639586108, 'subsample': 0.75, 'colsample_bytree': 0.45, 'reg_lambda': 63.00065953319189, 'reg_alpha': 0.1255111517297383, 'gamma': 32.7249944781739, 'early_stopping_rounds': 50}. Best is trial 0 with value: 0.380952380952381.
# [I 2026-06-05 10:33:44,896] Trial 1 finished with value: 0.3472429210134128 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05903473962504268, 'max_depth': 4, 'min_child_weight': 192.77345924989356, 'subsample': 0.65, 'colsample_bytree': 0.45, 'reg_lambda': 65.6118263910571, 'reg_alpha': 0.32877474139911184, 'gamma': 26.92085933774804, 'early_stopping_rounds': 35}. Best is trial 0 with value: 0.380952380952381.
# [I 2026-06-05 10:37:08,014] Trial 2 finished with value: 0.3189227498228207 and parameters: {'n_estimators': 1600, 'learning_rate': 0.03773298947682867, 'max_depth': 4, 'min_child_weight': 125.9032537218751, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.5, 'reg_lambda': 160.02711590046482, 'reg_alpha': 0.21839352923182975, 'gamma': 26.741985453031397, 'early_stopping_rounds': 35}. Best is trial 0 with value: 0.380952380952381.
# [I 2026-06-05 10:40:52,098] Trial 3 finished with value: 0.35509838998211096 and parameters: {'n_estimators': 1600, 'learning_rate': 0.03836938850941578, 'max_depth': 4, 'min_child_weight': 105.26285399045072, 'subsample': 0.8, 'colsample_bytree': 0.6, 'reg_lambda': 165.62864222126396, 'reg_alpha': 0.3292529363110524, 'gamma': 19.660425938108524, 'early_stopping_rounds': 35}. Best is trial 0 with value: 0.380952380952381.
# [I 2026-06-05 10:44:08,986] Trial 4 finished with value: 0.34713855421686746 and parameters: {'n_estimators': 1000, 'learning_rate': 0.04570678171513766, 'max_depth': 4, 'min_child_weight': 102.74848087273043, 'subsample': 0.8, 'colsample_bytree': 0.5, 'reg_lambda': 133.43560879938406, 'reg_alpha': 0.3385226783451977, 'gamma': 26.841156360022783, 'early_stopping_rounds': 35}. Best is trial 0 with value: 0.380952380952381.
# [I 2026-06-05 10:47:43,141] Trial 5 finished with value: 0.3971486761710794 and parameters: {'n_estimators': 1800, 'learning_rate': 0.05315126690360909, 'max_depth': 4, 'min_child_weight': 209.75182402990367, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 195.95323977664822, 'reg_alpha': 0.14136637008121844, 'gamma': 21.331708661125468, 'early_stopping_rounds': 50}. Best is trial 5 with value: 0.3971486761710794.
# [I 2026-06-05 10:51:30,461] Trial 6 finished with value: 0.36162923486867143 and parameters: {'n_estimators': 1200, 'learning_rate': 0.04051224362252231, 'max_depth': 4, 'min_child_weight': 192.21112454131898, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.5, 'reg_lambda': 111.72985922229381, 'reg_alpha': 0.17355056469855074, 'gamma': 31.637348672818675, 'early_stopping_rounds': 50}. Best is trial 5 with value: 0.3971486761710794.
# [I 2026-06-05 10:55:12,452] Trial 7 finished with value: 0.3645279934613813 and parameters: {'n_estimators': 1600, 'learning_rate': 0.03895686928861168, 'max_depth': 4, 'min_child_weight': 100.43634461193822, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 147.24875035820583, 'reg_alpha': 2.043455498416139, 'gamma': 19.258759079479535, 'early_stopping_rounds': 35}. Best is trial 5 with value: 0.3971486761710794.
# [I 2026-06-05 10:58:26,352] Trial 8 finished with value: 0.3168249660786974 and parameters: {'n_estimators': 1800, 'learning_rate': 0.048974686900500504, 'max_depth': 4, 'min_child_weight': 129.8096529285391, 'subsample': 0.65, 'colsample_bytree': 0.5, 'reg_lambda': 80.94873814926667, 'reg_alpha': 1.7361170890393298, 'gamma': 28.838477013038624, 'early_stopping_rounds': 35}. Best is trial 5 with value: 0.3971486761710794.
# [I 2026-06-05 11:01:57,693] Trial 9 finished with value: 0.37662337662337664 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05140752209262985, 'max_depth': 4, 'min_child_weight': 182.18392564026686, 'subsample': 0.75, 'colsample_bytree': 0.6, 'reg_lambda': 103.92118790879236, 'reg_alpha': 0.7728716861851781, 'gamma': 25.268197312095346, 'early_stopping_rounds': 50}. Best is trial 5 with value: 0.3971486761710794.
# [I 2026-06-05 11:06:28,372] Trial 10 finished with value: 0.42857142857142855 and parameters: {'n_estimators': 1800, 'learning_rate': 0.052816003638609325, 'max_depth': 4, 'min_child_weight': 214.77884206078636, 'subsample': 0.75, 'colsample_bytree': 0.55, 'reg_lambda': 191.87100317299922, 'reg_alpha': 4.271906202534824, 'gamma': 22.84635815570424, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:10:04,769] Trial 11 finished with value: 0.3547044129891757 and parameters: {'n_estimators': 1800, 'learning_rate': 0.05316556940205874, 'max_depth': 4, 'min_child_weight': 214.34720860084227, 'subsample': 0.75, 'colsample_bytree': 0.55, 'reg_lambda': 218.66684503570153, 'reg_alpha': 4.020706829014184, 'gamma': 22.07547561979085, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:14:32,991] Trial 12 finished with value: 0.40911161731207285 and parameters: {'n_estimators': 1800, 'learning_rate': 0.04543672300488414, 'max_depth': 4, 'min_child_weight': 214.91057540884964, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 201.50053733527497, 'reg_alpha': 0.8256545436331726, 'gamma': 22.290712832979548, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:18:25,122] Trial 13 finished with value: 0.3676341248900616 and parameters: {'n_estimators': 1400, 'learning_rate': 0.04390422214968389, 'max_depth': 4, 'min_child_weight': 159.915930446115, 'subsample': 0.75, 'colsample_bytree': 0.6, 'reg_lambda': 182.81344851868715, 'reg_alpha': 4.936517398170747, 'gamma': 23.307993910675975, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:22:41,891] Trial 14 finished with value: 0.35720680393912263 and parameters: {'n_estimators': 1800, 'learning_rate': 0.04277478829793423, 'max_depth': 4, 'min_child_weight': 165.04709829621558, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.55, 'reg_lambda': 127.67503519118142, 'reg_alpha': 0.8899836557699989, 'gamma': 23.734801542239993, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:27:27,534] Trial 15 finished with value: 0.38898601398601396 and parameters: {'n_estimators': 1600, 'learning_rate': 0.048093142088374945, 'max_depth': 4, 'min_child_weight': 214.73358817602025, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 214.428270164222, 'reg_alpha': 1.6437917395045412, 'gamma': 18.154322915971647, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:31:31,984] Trial 16 finished with value: 0.3587328767123288 and parameters: {'n_estimators': 1400, 'learning_rate': 0.03539676389769731, 'max_depth': 4, 'min_child_weight': 142.78226840786186, 'subsample': 0.75, 'colsample_bytree': 0.6, 'reg_lambda': 95.19851202021341, 'reg_alpha': 2.661299141395045, 'gamma': 21.453973776479714, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:36:27,309] Trial 17 finished with value: 0.41749502982107356 and parameters: {'n_estimators': 1800, 'learning_rate': 0.055958676995493006, 'max_depth': 4, 'min_child_weight': 200.74981686453108, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 171.54648316954604, 'reg_alpha': 1.1537876400456566, 'gamma': 24.742662103070288, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:40:29,283] Trial 18 finished with value: 0.37816931671680276 and parameters: {'n_estimators': 1600, 'learning_rate': 0.05702359931616357, 'max_depth': 4, 'min_child_weight': 196.88511004784337, 'subsample': 0.75, 'colsample_bytree': 0.5, 'reg_lambda': 170.223685311083, 'reg_alpha': 1.2087071085979488, 'gamma': 29.46087777029534, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:44:17,033] Trial 19 finished with value: 0.3465982028241335 and parameters: {'n_estimators': 1400, 'learning_rate': 0.05458842944883161, 'max_depth': 4, 'min_child_weight': 170.04708194947142, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.6, 'reg_lambda': 133.55674391325113, 'reg_alpha': 3.2154546223488083, 'gamma': 34.628628673255335, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:48:14,576] Trial 20 finished with value: 0.34724931720639873 and parameters: {'n_estimators': 1800, 'learning_rate': 0.049736684539986614, 'max_depth': 4, 'min_child_weight': 150.54196484424924, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 80.17994995387768, 'reg_alpha': 0.5947745859662942, 'gamma': 24.408669717656657, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:53:07,943] Trial 21 finished with value: 0.42202683942619157 and parameters: {'n_estimators': 1800, 'learning_rate': 0.055782905130898654, 'max_depth': 4, 'min_child_weight': 203.0413487992811, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 190.9072122256439, 'reg_alpha': 0.4750117457704234, 'gamma': 23.03248341881774, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 11:56:46,492] Trial 22 finished with value: 0.3473808586057503 and parameters: {'n_estimators': 1800, 'learning_rate': 0.054563669866183814, 'max_depth': 4, 'min_child_weight': 199.88525647649598, 'subsample': 0.8, 'colsample_bytree': 0.55, 'reg_lambda': 150.93825467849246, 'reg_alpha': 0.5583391396836817, 'gamma': 24.956060513429783, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 12:00:23,882] Trial 23 finished with value: 0.377924944812362 and parameters: {'n_estimators': 1600, 'learning_rate': 0.05653250931491342, 'max_depth': 4, 'min_child_weight': 180.69120702035323, 'subsample': 0.75, 'colsample_bytree': 0.55, 'reg_lambda': 181.3971765327779, 'reg_alpha': 1.1959876527910391, 'gamma': 20.277514382802128, 'early_stopping_rounds': 50}. Best is trial 10 with value: 0.42857142857142855.
# [I 2026-06-05 12:04:53,077] Trial 24 finished with value: 0.4297341291372762 and parameters: {'n_estimators': 1800, 'learning_rate': 0.059981035519663835, 'max_depth': 4, 'min_child_weight': 200.57871892009817, 'subsample': 0.8, 'colsample_bytree': 0.5, 'reg_lambda': 52.398281426388344, 'reg_alpha': 0.4426892641263967, 'gamma': 28.486803515487857, 'early_stopping_rounds': 50}. Best is trial 24 with value: 0.4297341291372762.
# best_params_path  : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00/optuna__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25/full/best_params.json
# pipeline_summary  : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00/optuna__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25/optuna_pipeline_summary.json
# threshold_path    : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00/ml_07__r00__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25_threshold.json
# metrics_path      : /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00/ml_07__r00__ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25_metrics_val.json

# %% [markdown]
# # 03_final test 잠금

# %%
# final test는 기본 잠금 상태다. 확정된 full artifact가 있을 때만 RUN_FINAL_TEST=True로 전환한다.
if RUN_FINAL_TEST:
    # confirm_final_test=True를 명시해 test 평가가 의도된 실행임을 남긴다.
    test_config = ml_test.TestConfig(
        test_path=TEST_PATH,
        output_dir=OUT_DIR,
        model_file_name=MODEL_FILE_NAME,
        feature_columns_file_name=FEATURE_COLUMNS_FILE_NAME,
        train_summary_file_name=TRAIN_SUMMARY_FILE_NAME,
        threshold_file_name=THRESHOLD_FILE_NAME,
        metrics_file_name=METRICS_TEST_FILE_NAME,
        confusion_matrix_file_name=CONFUSION_MATRIX_TEST_FILE_NAME,
        confirm_final_test=True,
        overwrite=OVERWRITE_OUTPUTS,
        encoding_manifest_path=ENCODING_MANIFEST_PATH,
        export_feature_assoc=EXPORT_FEATURE_ASSOC,
    )
    test_result = ml_test.test_xgb(test_config)
    print("metrics_path:", test_result.metrics_path)
else:
    print("RUN_FINAL_TEST=False: final test locked")
# Out:
# RUN_FINAL_TEST=False: final test locked

# %% [markdown]
# # 04_artifact 요약
#
# 저장된 train/validation/final-test artifact를 다시 읽어 실제 학습에 사용된 feature 목록과 metric을 확인한다. 이 섹션은 평가를 새로 실행하지 않는다.

# %%
import json
from pathlib import Path

import pandas as pd


def _read_json(path: Path) -> dict:
    with Path(path).open(encoding="utf-8") as f:
        return json.load(f)


def _artifact_paths(out_dir: Path) -> dict[str, Path]:
    return {
        "model": out_dir / MODEL_FILE_NAME,
        "feature_columns": out_dir / FEATURE_COLUMNS_FILE_NAME,
        "train_summary": out_dir / TRAIN_SUMMARY_FILE_NAME,
        "scores_train_summary": out_dir / SCORES_TRAIN_SUMMARY_FILE_NAME,
        "feature_importance": out_dir / FEATURE_IMPORTANCE_FILE_NAME,
        "threshold": out_dir / THRESHOLD_FILE_NAME,
        "metrics_val": out_dir / METRICS_VAL_FILE_NAME,
        "confusion_matrix_val": out_dir / CONFUSION_MATRIX_VAL_FILE_NAME,
        "metrics_test": out_dir / METRICS_TEST_FILE_NAME,
        "confusion_matrix_test": out_dir / CONFUSION_MATRIX_TEST_FILE_NAME,
    }


def _load_actual_feature_columns(paths: dict[str, Path]) -> list[str]:
    feature_columns_path = paths["feature_columns"]
    if feature_columns_path.exists():
        return list(_read_json(feature_columns_path)["feature_columns"])

    approve_table = pd.read_csv(FEATURE_COLUMNS_PATH, encoding="utf-8-sig", dtype={"used_in_ml": "string"})
    return approve_table.loc[approve_table["used_in_ml"] == "TRUE", "column_name"].astype(str).tolist()


def _build_feature_summary(paths: dict[str, Path]) -> tuple[pd.DataFrame, pd.DataFrame]:
    actual_features = _load_actual_feature_columns(paths)
    actual_df = pd.DataFrame({
        "feature_order": range(1, len(actual_features) + 1),
        "column_name": actual_features,
    })

    approve_table = pd.read_csv(FEATURE_COLUMNS_PATH, encoding="utf-8-sig", dtype={"used_in_ml": "string"})
    contract_cols = [
        "column_name",
        "used_in_ml",
        "feature_group",
        "dtype",
        "xgb_feature_type",
        "encoding",
        "source_column",
        "excluded_reason",
        "leakage_risk",
        "selection_note",
    ]
    contract_cols = [col for col in contract_cols if col in approve_table.columns]
    feature_summary = actual_df.merge(approve_table[contract_cols], on="column_name", how="left")

    if paths["feature_importance"].exists():
        importance = pd.read_csv(paths["feature_importance"])
        importance = importance.rename(columns={"feature": "column_name"})
        importance_cols = [
            "column_name",
            "rank_by_gain",
            "importance_gain",
            "importance_weight",
            "importance_cover",
        ]
        importance_cols = [col for col in importance_cols if col in importance.columns]
        feature_summary = feature_summary.merge(importance[importance_cols], on="column_name", how="left")

    manifest_features = []
    if ENCODING_MANIFEST_PATH.exists():
        manifest_features = list(_read_json(ENCODING_MANIFEST_PATH).get("feature_columns", []))

    approved_features = approve_table.loc[
        approve_table["used_in_ml"] == "TRUE", "column_name"
    ].astype(str).tolist()
    actual_set = set(actual_features)
    alignment_rows = []
    for feature_name in manifest_features:
        if feature_name not in actual_set:
            alignment_rows.append({
                "column_name": feature_name,
                "source": "manifest_only",
                "used_in_approve_contract": feature_name in approved_features,
                "used_in_trained_model": False,
            })
    for feature_name in approved_features:
        if feature_name not in actual_set:
            alignment_rows.append({
                "column_name": feature_name,
                "source": "approve_only",
                "used_in_approve_contract": True,
                "used_in_trained_model": False,
            })
    alignment_df = pd.DataFrame(alignment_rows)
    return feature_summary, alignment_df


def _build_run_summary(paths: dict[str, Path]) -> pd.DataFrame:
    if not paths["train_summary"].exists():
        return pd.DataFrame([{"status": "missing_train_summary", "path": str(paths["train_summary"])}])

    train_summary = _read_json(paths["train_summary"])
    threshold_payload = _read_json(paths["threshold"]) if paths["threshold"].exists() else {}
    xgb_params = train_summary.get("xgboost_params", {})
    xgb_acceleration = train_summary.get("xgboost_acceleration", {})
    run_metadata = train_summary.get("run_metadata", {})
    return pd.DataFrame([
        {
            "status": "ok",
            "export_experiment_id": run_metadata.get("export_experiment_id"),
            "input_run_id": run_metadata.get("input_run_id"),
            "model_run_id": run_metadata.get("model_run_id"),
            "run_kind": run_metadata.get("run_kind"),
            "sampled": train_summary.get("sampled"),
            "sample_rows": train_summary.get("sample_rows"),
            "feature_count": train_summary.get("feature_count"),
            "categorical_feature_count": len(train_summary.get("categorical_feature_columns", [])),
            "train_rows": train_summary.get("train_rows"),
            "val_rows": train_summary.get("val_rows"),
            "train_positive_ratio": train_summary.get("train_positive_ratio"),
            "scale_pos_weight": train_summary.get("scale_pos_weight"),
            "best_iteration": train_summary.get("best_iteration"),
            "best_score": train_summary.get("best_score"),
            "threshold_strategy": threshold_payload.get("threshold_strategy"),
            "threshold": threshold_payload.get("threshold"),
            "n_estimators": xgb_params.get("n_estimators"),
            "max_depth": xgb_params.get("max_depth"),
            "learning_rate": xgb_params.get("learning_rate"),
            "enable_categorical": xgb_params.get("enable_categorical"),
            "requested_accelerator": xgb_acceleration.get("requested_accelerator"),
            "resolved_accelerator": xgb_acceleration.get("resolved_accelerator"),
            "xgboost_tree_method": xgb_acceleration.get("xgboost_tree_method", xgb_params.get("tree_method")),
            "xgboost_predictor": xgb_acceleration.get("xgboost_predictor", xgb_params.get("predictor")),
            "gpu_fallback_reason": xgb_acceleration.get("gpu_fallback_reason"),
            "training_time_sec": train_summary.get("training_time_sec"),
            "memory_mb": train_summary.get("memory_mb"),
        }
    ])


def _metric_row(name: str, path: Path) -> dict:
    if not path.exists():
        return {"split": name, "status": "missing", "path": str(path)}

    payload = _read_json(path)
    metrics = payload.get("metrics", {})
    label_info = payload.get("label_summary", {})
    score_info = payload.get("score_profile", {})
    runtime_sec = payload.get("runtime_sec", {})
    total_runtime = runtime_sec.get("total_validate_xgb", runtime_sec.get("total_test_xgb"))

    return {
        "split": payload.get("split", name),
        "status": "ok",
        "sampled": payload.get("sampled"),
        "feature_count": payload.get("feature_count"),
        "feature_columns_hash": payload.get("feature_columns_hash"),
        "threshold_strategy": payload.get("threshold_strategy"),
        "threshold": metrics.get("threshold", payload.get("threshold")),
        "f1": metrics.get("f1"),
        "recall": metrics.get("recall"),
        "precision": metrics.get("precision"),
        "average_precision": metrics.get("average_precision"),
        "tp": metrics.get("tp"),
        "fp": metrics.get("fp"),
        "fn": metrics.get("fn"),
        "tn": metrics.get("tn"),
        "positive_count": label_info.get("positive_count"),
        "positive_ratio": label_info.get("positive_ratio"),
        "predicted_positive_count": score_info.get("predicted_positive_count"),
        "predicted_positive_rate": score_info.get("predicted_positive_rate"),
        "memory_mb": payload.get("memory_mb"),
        "total_runtime_sec": total_runtime,
        "path": str(path),
    }


artifact_paths = _artifact_paths(OUT_DIR)
artifact_status = pd.DataFrame([
    {"artifact": name, "exists": path.exists(), "path": str(path)}
    for name, path in artifact_paths.items()
])

feature_summary_df, feature_alignment_df = _build_feature_summary(artifact_paths)
run_summary_df = _build_run_summary(artifact_paths)
metric_summary_df = pd.DataFrame([
    _metric_row("val", artifact_paths["metrics_val"]),
    _metric_row("test", artifact_paths["metrics_test"]),
])
if "threshold_strategy" in metric_summary_df.columns:
    metric_summary_df["threshold_strategy"] = metric_summary_df["threshold_strategy"].astype("object")
if artifact_paths["threshold"].exists() and "threshold_strategy" in metric_summary_df.columns:
    threshold_payload = _read_json(artifact_paths["threshold"])
    metric_summary_df.loc[metric_summary_df["split"] == "val", "threshold_strategy"] = threshold_payload.get("threshold_strategy")

print("OUT_DIR:", OUT_DIR)
print("Actual trained feature count:", len(feature_summary_df))
display(artifact_status)

print("Train/threshold run summary")
display(run_summary_df)

print("Actual trained feature list and metadata")
display(feature_summary_df)

if feature_alignment_df.empty:
    print("No manifest/approve feature mismatch against trained feature_columns.json.")
else:
    print("Features present in manifest or approve contract but not in trained feature_columns.json")
    display(feature_alignment_df)

print("Validation / final test metrics from saved artifacts")
display(metric_summary_df)

if not artifact_paths["metrics_test"].exists():
    print("metrics_test.json not found: final test has not been evaluated for this OUT_DIR.")
# Out:
# OUT_DIR: /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r00
# Actual trained feature count: 182
#                 artifact  exists  \
# 0                  model    True
# 1        feature_columns    True
# 2          train_summary    True
# 3   scores_train_summary    True
# 4     feature_importance    True
# 5              threshold    True
# 6            metrics_val    True
# 7   confusion_matrix_val    True
# 8           metrics_test   False
# 9  confusion_matrix_test   False
#
#                                                 path
# 0  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 1  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 2  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 3  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 4  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 5  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 6  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 7  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 8  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 9  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# Train/threshold run summary
#   status export_experiment_id input_run_id  \
# 0     ok                ml_07          r00
#
#                                         model_run_id run_kind  sampled  \
# 0  ml07-d00-md4-top12-plus-fanin-formatoptuna-f1-t25     None    False
#
#   sample_rows  feature_count  categorical_feature_count  train_rows  ...  \
# 0        None            182                          6     3046186  ...
#
#    max_depth  learning_rate  enable_categorical  requested_accelerator  \
# 0          4       0.059981                True                   auto
#
#    resolved_accelerator xgboost_tree_method  xgboost_predictor  \
# 0                  cuda            gpu_hist      gpu_predictor
#
#    gpu_fallback_reason  training_time_sec     memory_mb
# 0                 None          92.419597  17781.527344
#
# [1 rows x 28 columns]
# Actual trained feature list and metadata
#      feature_order                                        column_name  \
# 0                1                             amount__current__value
# 1                2                             amount__current__log1p
# 2                3                    amount_received__current__value
# 3                4                    amount_received__current__log1p
# 4                5        timehist__sender__out__tx_count__count__w1h
# ..             ...                                                ...
# 177            178  flowbalance__receiver__net__amount__in_out_rat...
# 178            179  flowbalance__receiver__net__amount__in_out_rat...
# 179            180  passflow__sender__in_then_out__current_to_last...
# 180            181  passflow__sender__in_then_out__current_to_last...
# 181            182  passflow__sender__in_then_out__current_to_last...
#
#     used_in_ml         feature_group    dtype xgb_feature_type     encoding  \
# 0         TRUE  parent_ml04_selected  float64                q  passthrough
# 1         TRUE  parent_ml04_selected  float64                q  passthrough
# 2         TRUE  parent_ml04_selected  float64                q  passthrough
# 3         TRUE  parent_ml04_selected  float64                q  passthrough
# 4         TRUE  parent_ml04_selected  float32                q  passthrough
# ..         ...                   ...      ...              ...          ...
# 177       TRUE       ratio_transform  float32                q  passthrough
# 178       TRUE       ratio_transform  float32                q  passthrough
# 179       TRUE       ratio_transform  float32                q  passthrough
# 180       TRUE       ratio_transform  float32                q  passthrough
# 181       TRUE       ratio_transform  float32                q  passthrough
#
#                                          source_column excluded_reason  \
# 0                               amount__current__value             NaN
# 1                               amount__current__log1p             NaN
# 2                      amount_received__current__value             NaN
# 3                      amount_received__current__log1p             NaN
# 4          timehist__sender__out__tx_count__count__w1h             NaN
# ..                                                 ...             ...
# 177  flowbalance__receiver__net__amount__in_out_rat...             NaN
# 178  flowbalance__receiver__net__amount__in_out_rat...             NaN
# 179  passflow__sender__in_then_out__current_to_last...             NaN
# 180  passflow__sender__in_then_out__current_to_last...             NaN
# 181  passflow__sender__in_then_out__current_to_last...             NaN
#
#                             leakage_risk  \
# 0    inherited_from_ml04_parent_contract
# 1    inherited_from_ml04_parent_contract
# 2    inherited_from_ml04_parent_contract
# 3    inherited_from_ml04_parent_contract
# 4    inherited_from_ml04_parent_contract
# ..                                   ...
# 177                                  low
# 178                                  low
# 179                                  low
# 180                                  low
# 181                                  low
#
#                                         selection_note  rank_by_gain  \
# 0    carried forward from ML-04 parent selected ML ...            70
# 1    carried forward from ML-04 parent selected ML ...            62
# 2    carried forward from ML-04 parent selected ML ...            48
# 3    carried forward from ML-04 parent selected ML ...            35
# 4    carried forward from ML-04 parent selected ML ...            22
# ..                                                 ...           ...
# 177          generated by ML-07 ratio transform policy           165
# 178          generated by ML-07 ratio transform policy           114
# 179          generated by ML-07 ratio transform policy           129
# 180          generated by ML-07 ratio transform policy           108
# 181          generated by ML-07 ratio transform policy           143
#
#      importance_gain  importance_weight  importance_cover
# 0        1095.860229              482.0      44696.425781
# 1        1179.433105              210.0      43037.472656
# 2        1524.054321              454.0      45500.730469
# 3        2892.449707              206.0      54583.222656
# 4        4366.673340               53.0      47564.417969
# ..               ...                ...               ...
# 177       512.622131              242.0      45789.304688
# 178       719.005310              292.0      33212.457031
# 179       637.605652              105.0      61962.050781
# 180       740.223877              130.0      40351.589844
# 181       595.831970              194.0      31559.210938
#
# [182 rows x 15 columns]
# Features present in manifest or approve contract but not in trained feature_columns.json
#                                           column_name         source  \
# 0            timehist__sender__out__amount__mean__w1h  manifest_only
# 1             timehist__sender__out__amount__std__w1h  manifest_only
# 2         timehist__sender__out__tx_count__count__w6h  manifest_only
# 3            timehist__sender__out__amount__mean__w6h  manifest_only
# 4             timehist__sender__out__amount__std__w6h  manifest_only
# 5             timehist__sender__out__amount__std__w1d  manifest_only
# 6             timehist__sender__out__amount__sum__w3d  manifest_only
# 7            timehist__sender__out__amount__mean__w3d  manifest_only
# 8             timehist__sender__out__amount__max__w3d  manifest_only
# 9             timehist__sender__out__amount__sum__w7d  manifest_only
# 10           timehist__receiver__in__amount__std__w1h  manifest_only
# 11       timehist__receiver__in__tx_count__count__w6h  manifest_only
# 12           timehist__receiver__in__amount__sum__w6h  manifest_only
# 13          timehist__receiver__in__amount__mean__w6h  manifest_only
# 14           timehist__receiver__in__amount__std__w6h  manifest_only
# 15           timehist__receiver__in__amount__max__w6h  manifest_only
# 16           timehist__receiver__in__amount__sum__w1d  manifest_only
# 17          timehist__receiver__in__amount__mean__w1d  manifest_only
# 18           timehist__receiver__in__amount__std__w1d  manifest_only
# 19           timehist__receiver__in__amount__max__w1d  manifest_only
# 20           timehist__receiver__in__amount__sum__w3d  manifest_only
# 21          timehist__receiver__in__amount__mean__w3d  manifest_only
# 22           timehist__receiver__in__amount__max__w3d  manifest_only
# 23       timehist__receiver__in__tx_count__count__w7d  manifest_only
# 24           timehist__receiver__in__amount__max__w7d  manifest_only
# 25      accountstats__receiver__in__amount__mean__w1d  manifest_only
# 26        accountstats__sender__out__amount__std__w1d  manifest_only
# 27       accountstats__receiver__in__amount__std__w1d  manifest_only
# 28       accountstats__sender__out__amount__mean__w3d  manifest_only
# 29      accountstats__receiver__in__amount__mean__w3d  manifest_only
# 30       accountstats__sender__out__amount__mean__w7d  manifest_only
# 31      accountstats__receiver__in__amount__mean__w7d  manifest_only
# 32       accountstats__receiver__in__amount__std__w7d  manifest_only
# 33        accountstats__sender__out__amount__sum__w3d  manifest_only
# 34        accountstats__sender__out__amount__sum__w7d  manifest_only
# 35         accountstats__sender__in__amount__sum__w6h  manifest_only
# 36         accountstats__sender__in__amount__sum__w3d  manifest_only
# 37       accountstats__receiver__in__amount__sum__w6h  manifest_only
# 38       accountstats__receiver__in__amount__sum__w1d  manifest_only
# 39       accountstats__receiver__in__amount__sum__w3d  manifest_only
# 40       accountstats__receiver__in__amount__sum__w7d  manifest_only
# 41  fanin__receiver__in__counterparty_amount__effe...  manifest_only
# 42   pair__sender_receiver__forward__amount__sum__w1d  manifest_only
# 43   pair__sender_receiver__forward__amount__sum__w3d  manifest_only
# 44  pair__sender_receiver__forward__amount__mean__w1d  manifest_only
# 45   pair__sender_receiver__forward__amount__std__w1d  manifest_only
# 46   pair__sender_receiver__forward__amount__max__w1d  manifest_only
# 47  pair__sender_receiver__forward__amount__mean__w3d  manifest_only
# 48   pair__sender_receiver__forward__amount__std__w3d  manifest_only
# 49   pair__sender_receiver__forward__amount__max__w3d  manifest_only
# 50   pair__sender_receiver__forward__amount__std__w7d  manifest_only
# 51  flowbalance__sender__net__amount__residual_abs...  manifest_only
# 52  passflow__receiver__in_then_out__historical_se...  manifest_only
# 53          amount__paid_recv_ratio__clip_train_p9999  manifest_only
# 54  pair__sender_receiver__bidirectional__amount_r...  manifest_only
#
#     used_in_approve_contract  used_in_trained_model
# 0                      False                  False
# 1                      False                  False
# 2                      False                  False
# 3                      False                  False
# 4                      False                  False
# 5                      False                  False
# 6                      False                  False
# 7                      False                  False
# 8                      False                  False
# 9                      False                  False
# 10                     False                  False
# 11                     False                  False
# 12                     False                  False
# 13                     False                  False
# 14                     False                  False
# 15                     False                  False
# 16                     False                  False
# 17                     False                  False
# 18                     False                  False
# 19                     False                  False
# 20                     False                  False
# 21                     False                  False
# 22                     False                  False
# 23                     False                  False
# 24                     False                  False
# 25                     False                  False
# 26                     False                  False
# 27                     False                  False
# 28                     False                  False
# 29                     False                  False
# 30                     False                  False
# 31                     False                  False
# 32                     False                  False
# 33                     False                  False
# 34                     False                  False
# 35                     False                  False
# 36                     False                  False
# 37                     False                  False
# 38                     False                  False
# 39                     False                  False
# 40                     False                  False
# 41                     False                  False
# 42                     False                  False
# 43                     False                  False
# 44                     False                  False
# 45                     False                  False
# 46                     False                  False
# 47                     False                  False
# 48                     False                  False
# 49                     False                  False
# 50                     False                  False
# 51                     False                  False
# 52                     False                  False
# 53                     False                  False
# 54                     False                  False
# Validation / final test metrics from saved artifacts
#   split   status sampled  feature_count  \
# 0   val       ok   False          182.0
# 1  test  missing     NaN            NaN
#
#                                 feature_columns_hash threshold_strategy  \
# 0  65becf4ba55e75aa95905ff4b739ad8d0200fa3b7e8d53...             max_f1
# 1                                                NaN                NaN
#
#    threshold        f1    recall  precision  ...     fp     fn         tn  \
# 0   0.989393  0.429734  0.365651   0.521053  ...  364.0  687.0  1014186.0
# 1        NaN       NaN       NaN        NaN  ...    NaN    NaN        NaN
#
#    positive_count  positive_ratio  predicted_positive_count  \
# 0          1083.0        0.001066                     760.0
# 1             NaN             NaN                       NaN
#
#    predicted_positive_rate  memory_mb  total_runtime_sec  \
# 0                 0.000748  18523.625          69.930302
# 1                      NaN        NaN                NaN
#
#                                                 path
# 0  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
# 1  /mnt/d/AML_git/Graph_AML/ml/ml-07/ml_outputs/r...
#
# [2 rows x 22 columns]
# metrics_test.json not found: final test has not been evaluated for this OUT_DIR.
